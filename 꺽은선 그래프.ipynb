# %%
import csv

r = input('2017~2019: ')

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)
header = next(data)

bb = 0
cc = 0
dd = 0
rr = 0
for i in data:
    if r == i[0] and '사고건수' in i[1]:
        bb = int(i[2].replace(',',''))
        rr = int(i[0])
        print("%d년도 사고건수 %d"%(rr,bb))
        
    elif r == i[0] and '부상자수' in i[1]:
        cc = int(i[2].replace(',',''))
        rr = int(i[0])
        print("%d년도 부상자수 %d"%(rr,cc))
        
    elif r == i[0] and '사망건수' in i[1]:
        dd = int(i[2].replace(',',''))
        rr = int(i[0])
        print("%d년도 사망건수 %d"%(rr,dd))


f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)
header = next(data)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        ds = i[4]
        print('동구 사고건수 :',ds)     
    elif r == i[0] and '사망건수' in i[1]:
        dss = i[4]
        print('동구 사망건수 :',dss)
    elif r == i[0] and '부상자수' in i[1]:
        db = i[4]
        print('동구 부상자수 :',db) 
        
f.close()


f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        js = i[3]
        print('중구 사고건수 :',js)     
    elif r == i[0] and '사망건수' in i[1]:
        jss = i[3]
        print('중구 사망건수 :',jss)
    elif r == i[0] and '부상자수' in i[1]:
        jb = i[3]
        print('중구 부상자수 :',jb)

f.close()


f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        ss = i[5]
        print('서구 사고건수 :',ss)     
    elif r == i[0] and '사망건수' in i[1]:
        sss = i[5]
        print('서구 사망건수 :',sss)
    elif r == i[0] and '부상자수' in i[1]:
        sb = i[5]
        print('서구 부상자수 :',sb)

f.close()



f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        ns = i[6]
        print('남구 사고건수 :',ns)     
    elif r == i[0] and '사망건수' in i[1]:
        nss = i[6]
        print('남구 사망건수 :',nss)
    elif r == i[0] and '부상자수' in i[1]:
        nb = i[6]
        print('남구 부장자수 :',nb)

f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        sus = i[8]
        print('수성구 사고건수 :',sus)     
    elif r == i[0] and '사망건수' in i[1]:
        suss = i[8]
        print('수성구 사망건수 :',suss)
    elif r == i[0] and '부상자수' in i[1]:
        sub = i[8]
        print('수성구 부장자수 :',sub)

f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        bs = i[7]
    #    print('북부 사고건수 :',bs)     
    elif r == i[0] and '사망건수' in i[1]:
        bss = i[7]
    #    print('북부 사망건수 :',bss)
    elif r == i[0] and '부상자수' in i[1]:
        b3 = i[7]
   #     print('북부 부상자수 :',bb)

f.close()


f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        bbs = i[12]
     #   print('강북 사고건수 :',bbs)     
    elif r == i[0] and '사망건수' in i[1]:
        bbss = i[12]
      #  print('강북 사망건수 :',bbss)
    elif r == i[0] and '부상자수' in i[1]:
        bbb = i[12]
     #   print('강북 부상자수 :',bbb)

f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        dss = i[9]
    #    print('달서 사고건수 :',dss)     
    elif r == i[0] and '사망건수' in i[1]:
        ddss = i[9]
     #   print('달서 사망건수 :',ddss)
    elif r == i[0] and '부상자수' in i[1]:
        dsb = i[9]
      #  print('달서 부상자수 :',dsb)
        
f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        sss = i[10]
   #     print('성서 사고건수 :',sss)     
    elif r == i[0] and '사망건수' in i[1]:
        ssss = i[10]
     #   print('성서 사망건수 :',ssss)
    elif r == i[0] and '부상자수' in i[1]:
        ssb = i[10]
    #    print('성서 부상자수 :',ssb)
        
f.close()


f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        d1s = i[11]
        print('달성 사고건수 :',d1s)     
    elif r == i[0] and '사망건수' in i[1]:
        d2s = i[11]
        print('달성 사망건수 :',d2s)
    elif r == i[0] and '부상자수' in i[1]:
        d3b = i[11]
        print('달성 부상자수 :',d3b)
        
f.close()


replace_bbs = bbs.replace(",", "")
replace_bs = bs.replace(",", "")
h=int(replace_bbs)
hh=int(replace_bs)
replace_bss = bss.replace(",", "")
replace_bbss = bbss.replace(",", "")
h1=int(replace_bss)
h2=int(replace_bbss)
replace_b3 = b3.replace(",", "")
replace_bbb = bbb.replace(",", "")
h3=int(replace_b3)
h4=int(replace_bbb)

print('북구 사고 건수 : ',h+hh)
print('북구 사망 건수 : ',h1+h2)
print('북구 부상 자수 : ',h3+h4)

#######################################

replace_dss = dss.replace(",", "")
replace_sss = sss.replace(",", "")
h5=int(replace_dss)
hh6=int(replace_sss)
print('달서구 사고 건수 : ',h5+hh6)
###################################
replace_dss = dss.replace(",", "")
replace_sss = sss.replace(",", "")
h7=int(replace_dss)
h8=int(replace_sss)
print('달서구 사망 건수 : ',h7+h8)
########################################
replace_dsb = dsb.replace(",", "")
replace_ssb = ssb.replace(",", "")
h9=int(replace_dsb)
h10=int(replace_ssb)
print('달서구 사망 건수 : ',h9+h10)

f = open('drunk.csv',encoding = 'cp949')
data1 = csv.reader(f)

tt = 0

for m in data1 :
    if m[0] == '대구광역시'  and r == '2017':
        tt = int(m[8].replace(',',''))
        rr = int(r)
        print("%d년도 음주운전건수 %d"%(rr,tt))
    elif m[0] == '대구광역시'  and r == '2018':
        tt = int(m[11].replace(',',''))
        rr = int(r)
        print("%d년도 음주운전건수 %d"%(rr,tt))
    elif m[0] == '대구광역시'  and r == '2019':
        tt = int(m[14].replace(',',''))
        rr = int(r)
        print("%d년도 음주운전건수 %d"%(rr,tt))



f.close()

import matplotlib.pyplot as plt
from matplotlib import pyplot as plt 

traffic_accident = [dd,cc,bb,rr]

plt.bar(range(len(traffic_accident)),traffic_accident)
plt.show()







# #plt.rc('font',family = 'NanumGothic')
# plt.figure(figsize = (10,10))
# size = [bb,cc,dd,tt]
# label = ['qqq','qq2','qq3','qq4']
# #plt.axis('equal')
# plt.pie(size, labels = label, autopct = '%.1f%%',textprops={'fontsize':1},colors = 'colors')
# plt.legend()
# plt.show()
# Out:
# 2017~2019: 2017
# 2017년도 사고건수 12870
# 2017년도 사망건수 136
# 2017년도 부상자수 18336
# 동구 사고건수 : 1,575
# 동구 사망건수 : 19
# 동구 부상자수 : 2,281
# 중구 사고건수 : 994
# 중구 사망건수 : 6
# 중구 부상자수 : 1,421
# 서구 사고건수 : 1,294
# 서구 사망건수 : 15
# 서구 부상자수 : 1,853
# 남구 사고건수 : 813
# 남구 사망건수 : 9
# 남구 부장자수 : 1,171
# 수성구 사고건수 : 2,012
# 수성구 사망건수 : 20
# 수성구 부장자수 : 2,894
# 달성 사고건수 : 855
# 달성 사망건수 : 26
# 달성 부상자수 : 1,174
# 북구 사고 건수 :  2189
# 북구 사망 건수 :  22
# 북구 부상 자수 :  3035
# 달서구 사고 건수 :  3138
# 달서구 사망 건수 :  3138
# 달서구 사망 건수 :  4507
# 2017년도 음주운전건수 890

# %%
import csv

r = input('2017~2019: ')

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)
header = next(data)

bb = 0
cc = 0
dd = 0
rr = 0
for i in data:
    if r == i[0] and '사고건수' in i[1]:
        bb = int(i[2].replace(',',''))
        rr = int(i[0])
        print("%d년도 사고건수 %d"%(rr,bb))
        
    elif r == i[0] and '부상자수' in i[1]:
        cc = int(i[2].replace(',',''))
        rr = int(i[0])
        print("%d년도 부상자수 %d"%(rr,cc))
        
    elif r == i[0] and '사망건수' in i[1]:
        dd = int(i[2].replace(',',''))
        rr = int(i[0])
        print("%d년도 사망건수 %d"%(rr,dd))


f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)
header = next(data)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        ds = int(i[4].replace(',',''))
        print('동구 사고건수 :',ds)     
    elif r == i[0] and '사망건수' in i[1]:
        dss1 = int(i[4].replace(',',''))
        print('동구 사망건수 :',dss1)
    elif r == i[0] and '부상자수' in i[1]:
        db = int(i[4].replace(',',''))
        print('동구 부상자수 :',db) 
        
f.close()


f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        js = int(i[3].replace(',',''))
        print('중구 사고건수 :',js)     
    elif r == i[0] and '사망건수' in i[1]:
        jss = int(i[3].replace(',',''))
        print('중구 사망건수 :',jss)
    elif r == i[0] and '부상자수' in i[1]:
        jb = int(i[3].replace(',',''))
        print('중구 부상자수 :',jb)

f.close()


f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        ss = int(i[5].replace(',',''))
        print('서구 사고건수 :',ss)     
    elif r == i[0] and '사망건수' in i[1]:
        sss1 = int(i[5].replace(',',''))
        print('서구 사망건수 :',sss1)
    elif r == i[0] and '부상자수' in i[1]:
        sb = int(i[5].replace(',',''))
        print('서구 부상자수 :',sb)

f.close()



f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        ns = int(i[6].replace(',',''))
        print('남구 사고건수 :',ns)     
    elif r == i[0] and '사망건수' in i[1]:
        nss = int(i[6].replace(',',''))
        print('남구 사망건수 :',nss)
    elif r == i[0] and '부상자수' in i[1]:
        nb = int(i[6].replace(',',''))
        print('남구 부상자수 :',nb)

f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        sus = int(i[8].replace(',',''))
        print('수성구 사고건수 :',sus)     
    elif r == i[0] and '사망건수' in i[1]:
        suss = int(i[8].replace(',',''))
        print('수성구 사망건수 :',suss)
    elif r == i[0] and '부상자수' in i[1]:
        sub = int(i[8].replace(',',''))
        print('수성구 부상자수 :',sub)

f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        bs = int(i[7].replace(',',''))
    #    print('북부 사고건수 :',bs)     
    elif r == i[0] and '사망건수' in i[1]:
        bss = int(i[7].replace(',',''))
    #    print('북부 사망건수 :',bss)
    elif r == i[0] and '부상자수' in i[1]:
        b3 = int(i[7].replace(',',''))
   #     print('북부 부상자수 :',bb)

f.close()


f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        bbs = int(i[12].replace(',',''))
     #   print('강북 사고건수 :',bbs)     
    elif r == i[0] and '사망건수' in i[1]:
        bbss = int(i[12].replace(',',''))
      #  print('강북 사망건수 :',bbss)
    elif r == i[0] and '부상자수' in i[1]:
        bbb = int(i[12].replace(',',''))
     #   print('강북 부상자수 :',bbb)

f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        dss = int(i[9].replace(',',''))
    #    print('달서 사고건수 :',dss)     
    elif r == i[0] and '사망건수' in i[1]:
        ddss = int(i[9].replace(',',''))
     #   print('달서 사망건수 :',ddss)
    elif r == i[0] and '부상자수' in i[1]:
        dsb = int(i[9].replace(',',''))
      #  print('달서 부상자수 :',dsb)
        
f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        sss = int(i[10].replace(',',''))
   #     print('성서 사고건수 :',sss)     
    elif r == i[0] and '사망건수' in i[1]:
        ssss = int(i[10].replace(',',''))
     #   print('성서 사망건수 :',ssss)
    elif r == i[0] and '부상자수' in i[1]:
        ssb = int(i[10].replace(',',''))
    #    print('성서 부상자수 :',ssb)
        
f.close()


f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        d1s = int(i[11].replace(',',''))
        print('달성 사고건수 :',d1s)     
    elif r == i[0] and '사망건수' in i[1]:
        d2s = int(i[11].replace(',',''))
        print('달성 사망건수 :',d2s)
    elif r == i[0] and '부상자수' in i[1]:
        d3b = int(i[11].replace(',',''))
        print('달성 부상자수 :',d3b)
        
f.close()




print('북구 사고 건수 : ',bbs+bs)
print('북구 사망 건수 : ',bss+bbss)
print('북구 부상 자수 : ',b3+bbb)

#######################################


print('달서구 사고 건수 : ',dss+sss)
###################################

print('달서구 사망 건수 : ',ddss+ssss)
########################################


print('달서구 사망 건수 : ',dsb+ssb)

f = open('drunk.csv',encoding = 'cp949')
data1 = csv.reader(f)

tt = 0

for m in data1 :
    if m[0] == '대구광역시'  and r == '2017':
        tt = int(m[8].replace(',',''))
        rr = int(r)
        print("%d년도 음주운전건수 %d"%(rr,tt))
    elif m[0] == '대구광역시'  and r == '2018':
        tt = int(m[11].replace(',',''))
        rr = int(r)
        print("%d년도 음주운전건수 %d"%(rr,tt))
    elif m[0] == '대구광역시'  and r == '2019':
        tt = int(m[14].replace(',',''))
        rr = int(r)
        print("%d년도 음주운전건수 %d"%(rr,tt))



f.close()




# #plt.rc('font',family = 'NanumGothic')
# plt.figure(figsize = (10,10))
# size = [bb,cc,dd,tt]
# label = ['qqq','qq2','qq3','qq4']
# #plt.axis('equal')
# plt.pie(size, labels = label, autopct = '%.1f%%',textprops={'fontsize':1},colors = 'colors')
# plt.legend()
# plt.show()
# Out:
# 2017~2019: 2017
# 2017년도 사고건수 12870
# 2017년도 사망건수 136
# 2017년도 부상자수 18336
# 동구 사고건수 : 1575
# 동구 사망건수 : 19
# 동구 부상자수 : 2281
# 중구 사고건수 : 994
# 중구 사망건수 : 6
# 중구 부상자수 : 1421
# 서구 사고건수 : 1294
# 서구 사망건수 : 15
# 서구 부상자수 : 1853
# 남구 사고건수 : 813
# 남구 사망건수 : 9
# 남구 부상자수 : 1171
# 수성구 사고건수 : 2012
# 수성구 사망건수 : 20
# 수성구 부상자수 : 2894
# 달성 사고건수 : 855
# 달성 사망건수 : 26
# 달성 부상자수 : 1174
# 북구 사고 건수 :  2189
# 북구 사망 건수 :  22
# 북구 부상 자수 :  3035
# 달서구 사고 건수 :  3138
# 달서구 사망 건수 :  19
# 달서구 사망 건수 :  4507
# 2017년도 음주운전건수 890

# %%
# 한 주의 요일(0: 일, 1: 월 ~ 6: 토)
days = ['동구', '중구', '서구', '남구', '수성구','달성군','북구','달서구']
# 내가 사용한 돈(천원)
money_spent =  [ds, js, ss, ns, sus, d1s, bbs+bs, dss+sss]
# 친구가 사용한 돈(천원)
money_spent_2 = [dss, jss, sss ,nss, suss, d2s,  bss+bbss, dss+sss]
# 내가 사용한 돈을 그래프로 그립니다
plt.plot(days, money_spent)
# 같은 그림에 친구가 사용한 돈도 그래프로 그립니다
plt.plot(days, money_spent_2)
# 화면에 그래프를 보여줍니다
plt.show()

# %%
place = ['East', 'Jung', 'West', 'South ', 'Suseong','Dalseong','North ','Dalseo']

hurt =  [ds, js, ss, ns, sus, d1s, bbs+bs, dss+sss]



plt.plot(place, hurt)


plt.show()

# %%
place = ['East', 'Jung', 'West', 'South ', 'Suseong','Dalseong','North ','Dalseo']

die = [dss1, jss,sss1 ,nss, suss, d2s,  bss+bbss, ddss+ssss]

plt.plot(place, die)

plt.show()

# %%
place = ['East', 'Jung', 'West', 'South ', 'Suseong','Dalseong','North ','Dalseo']



accident = [db, jb, sb, nb,  sub, d3b, b3+bbb, dsb+ssb]

plt.plot(place, die)

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm


font_path = r'C:\Users\KB\Downloads\MaruBuri-Regular\MaruBuri-Regular.ttf'
fontprop = fm.FontProperties(fname=font_path, size=18)

place = ['East', 'Jung', 'West', 'South ', 'Suseong','Dalseong','North ','Dalseo']

hurt =  [ds, js, ss, ns, sus, d1s, bbs+bs, dss+sss]

plt.plot(place, hurt)

die = [dss1, jss,sss1 ,nss, suss, d2s,  bss+bbss, ddss+ssss]

plt.plot(place, die)

accident = [db, jb, sb, nb,  sub, d3b, b3+bbb, dsb+ssb]
#plt.plot(days, accident) days를 place로 바꾸지않아서 오류떳음
#북구 달서구에서 숫자값을 더할때 int 값으로 전화하지않아 숫자가 이상하게 출력됨
#ex a = 1,234 b=4,567 a+b = 123456
plt.plot(place, accident)
plt.title('대구 교통사고 통계',fontproperties=fontprop)
plt.xlabel('지역',fontproperties=fontprop)
plt.ylabel('건수',fontproperties=fontprop)
plt.legend(['hurt', 'die', 'accident'])
plt.savefig('sample.png')
plt.show()
