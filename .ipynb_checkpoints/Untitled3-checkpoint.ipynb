# %%
import csv
r = input('2017~2019: ')
f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)
header = next(data)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        b = i[2]
        print(b)
        
    elif r == i[0] and '부상자수' in i[1]:
        c = i[2]
        print(c)
        
    elif r == i[0] and '사망건수' in i[1]:
        d = i[2]
        print(d)
        
f.close()

#f = open('Daegu.csv',encoding = 'cp949')
#data1 = csv.reader(f)
#for i in date :
 #   if r == i[0] and '사건건수' in i[1] :
 #       dd= i[4]
#        print(dd)

import csv

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)
header = next(data)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        ds = i[4]
        print('동구 사고건수 :',ds)     
    elif r == i[0] and '사망건수' in i[1]:
        dss = i[4]
        print('동구 사망건수 :',dss)
    elif r == i[0] and '부상자수' in i[1]:
        db = i[4]
        print('동구 부장자수 :',db) 
        
f.close()


f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        js = i[3]
        print('중구 사고건수 :',js)     
    elif r == i[0] and '사망건수' in i[1]:
        jss = i[3]
        print('중구 사망건수 :',jss)
    elif r == i[0] and '부상자수' in i[1]:
        jb = i[3]
        print('중구 부장자수 :',jb)

f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        ss = i[5]
        print('서구 사고건수 :',ss)     
    elif r == i[0] and '사망건수' in i[1]:
        sss = i[5]
        print('서구 사망건수 :',sss)
    elif r == i[0] and '부상자수' in i[1]:
        sb = i[5]
        print('서구 부장자수 :',sb)

f.close()



f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        ns = i[6]
        print('남구 사고건수 :',ns)     
    elif r == i[0] and '사망건수' in i[1]:
        nss = i[6]
        print('남구 사망건수 :',nss)
    elif r == i[0] and '부상자수' in i[1]:
        nb = i[6]
        print('남구 부장자수 :',nb)

f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        sus = i[8]
        print('수성구 사고건수 :',sus)     
    elif r == i[0] and '사망건수' in i[1]:
        suss = i[8]
        print('수성구 사망건수 :',suss)
    elif r == i[0] and '부상자수' in i[1]:
        sub = i[8]
        print('수성구 부장자수 :',sub)

f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        bs = i[7]
        print('북부 사고건수 :',bs)     
    elif r == i[0] and '사망건수' in i[1]:
        bss = i[7]
        print('북부 사망건수 :',bss)
    elif r == i[0] and '부상자수' in i[1]:
        bb = i[7]
        print('북부 부상자수 :',bb)

f.close()
f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        bbs = i[12]
        print('강북 사고건수 :',bbs)     
    elif r == i[0] and '사망건수' in i[1]:
        bbss = i[12]
        print('강북 사망건수 :',bbss)
    elif r == i[0] and '부상자수' in i[1]:
        bbb = i[12]
        print('강북 부상자수 :',bbb)

f.close()









#for i in date :
  #  if t == i[4] and '사고건수' in i[1]:
 #       dd = i[4]
#        print(dd)

# %%
import csv
r = input('2017~2019: ')
f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)
header = next(data)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        b = i[2]
        print(b)
        
    elif r == i[0] and '부상자수' in i[1]:
        c = i[2]
        print(c)
        
    elif r == i[0] and '사망건수' in i[1]:
        d = i[2]
        print(d)
        
f.close()

#f = open('Daegu.csv',encoding = 'cp949')
#data1 = csv.reader(f)
#for i in date :
 #   if r == i[0] and '사건건수' in i[1] :
 #       dd= i[4]
#        print(dd)

import csv

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)
header = next(data)

for i in data:        
    if r == i[0] and ' 사망자수' in i[1]:
        dss = i[4]
        print('동구 사망건수 :',dss)
        
        
f.close()





#for i in date :
  #  if t == i[4] and '사고건수' in i[1]:
 #       dd = i[4]
#        print(dd)
