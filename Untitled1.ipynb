# %%
import csv
r = input('2017~2019: ')
f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)
header = next(data)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        b = i[2]
        print(b)
        
    elif r == i[0] and '부상자수' in i[1]:
        c = i[2]
        print(c)
        
    elif r == i[0] and '사망건수' in i[1]:
        d = i[2]
        print(d)
        
f.close()

#f = open('Daegu.csv',encoding = 'cp949')
#data1 = csv.reader(f)
#for i in date :
 #   if r == i[0] and '사건건수' in i[1] :
 #       dd= i[4]
#        print(dd)

import csv

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)
header = next(data)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        ds = i[4]
        print('동구 사고건수 :',ds)     
    elif r == i[0] and '사망건수' in i[1]:
        dss = i[4]
        print('동구 사망건수 :',dss)
    elif r == i[0] and '부상자수' in i[1]:
        db = i[4]
        print('동구 부장자수 :',db) 
        
f.close()


f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        js = i[3]
        print('중구 사고건수 :',js)     
    elif r == i[0] and '사망건수' in i[1]:
        jss = i[3]
        print('중구 사망건수 :',jss)
    elif r == i[0] and '부상자수' in i[1]:
        jb = i[3]
        print('중구 부장자수 :',jb)

f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        ss = i[5]
        print('서구 사고건수 :',ss)     
    elif r == i[0] and '사망건수' in i[1]:
        sss = i[5]
        print('서구 사망건수 :',sss)
    elif r == i[0] and '부상자수' in i[1]:
        sb = i[5]
        print('서구 부장자수 :',sb)

f.close()



f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        ns = i[6]
        print('남구 사고건수 :',ns)     
    elif r == i[0] and '사망건수' in i[1]:
        nss = i[6]
        print('남구 사망건수 :',nss)
    elif r == i[0] and '부상자수' in i[1]:
        nb = i[6]
        print('남구 부장자수 :',nb)

f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        sus = i[8]
        print('수성구 사고건수 :',sus)     
    elif r == i[0] and '사망건수' in i[1]:
        suss = i[8]
        print('수성구 사망건수 :',suss)
    elif r == i[0] and '부상자수' in i[1]:
        sub = i[8]
        print('수성구 부장자수 :',sub)

f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        bs = i[7]
    #    print('북부 사고건수 :',bs)     
    elif r == i[0] and '사망건수' in i[1]:
        bss = i[7]
    #    print('북부 사망건수 :',bss)
    elif r == i[0] and '부상자수' in i[1]:
        bb = i[7]
   #     print('북부 부상자수 :',bb)

f.close()
f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        bbs = i[12]
     #   print('강북 사고건수 :',bbs)     
    elif r == i[0] and '사망건수' in i[1]:
        bbss = i[12]
      #  print('강북 사망건수 :',bbss)
    elif r == i[0] and '부상자수' in i[1]:
        bbb = i[12]
     #   print('강북 부상자수 :',bbb)



f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        dss = i[9]
    #    print('달서 사고건수 :',dss)     
    elif r == i[0] and '사망건수' in i[1]:
        ddss = i[9]
     #   print('달서 사망건수 :',ddss)
    elif r == i[0] and '부상자수' in i[1]:
        dsb = i[9]
      #  print('달서 부상자수 :',dsb)
        
f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        sss = i[10]
   #     print('성서 사고건수 :',sss)     
    elif r == i[0] and '사망건수' in i[1]:
        ssss = i[10]
     #   print('성서 사망건수 :',ssss)
    elif r == i[0] and '부상자수' in i[1]:
        ssb = i[10]
    #    print('성서 부상자수 :',ssb)
        
f.close()


f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        d1s = i[11]
        print('달성 사고건수 :',d1s)     
    elif r == i[0] and '사망건수' in i[1]:
        d2s = i[11]
        print('달성 사망건수 :',d2s)
    elif r == i[0] and '부상자수' in i[1]:
        d3b = i[11]
        print('달성 부상자수 :',d3b)
        
f.close()


replace_bbs = bbs.replace(",", "")
replace_bs = bs.replace(",", "")
h=int(replace_bbs)
hh=int(replace_bs)
replace_bss = bss.replace(",", "")
replace_bbss = bbss.replace(",", "")
h1=int(replace_bss)
h2=int(replace_bbss)
replace_bb = bb.replace(",", "")
replace_bbb = bbb.replace(",", "")
h3=int(replace_bb)
h4=int(replace_bbb)

print('경북 사고 건수 : ',h+hh)
print('경북 사망 건수 : ',h1+h2)
print('경북 부상 자수 : ',h3+h4)

#######################################

replace_dss = dss.replace(",", "")
replace_sss = sss.replace(",", "")
h5=int(replace_dss)
hh6=int(replace_sss)
print('달서구 사고 건수 : ',h5+hh6)
###################################
replace_dss = dss.replace(",", "")
replace_sss = sss.replace(",", "")
h7=int(replace_dss)
h8=int(replace_sss)
print('달서구 사망 건수 : ',h7+h8)
########################################
replace_dsb = dsb.replace(",", "")
replace_ssb = ssb.replace(",", "")
h9=int(replace_dsb)
h10=int(replace_ssb)
print('달서구 사망 건수 : ',h7+h8)


import csv

r = input('2017~2019: ')

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)
header = next(data)

bb = 0
cc = 0
dd = 0
rr = 0
for i in data:
    if r == i[0] and '사고건수' in i[1]:
        bb = int(i[2].replace(',',''))
        rr = int(i[0])
        print("%d년도 사고건수 %d"%(rr,bb))
        
    elif r == i[0] and '부상자수' in i[1]:
        cc = int(i[2].replace(',',''))
        rr = int(i[0])
        print("%d년도 부상자수 %d"%(rr,cc))
        
    elif r == i[0] and '사망건수' in i[1]:
        dd = int(i[2].replace(',',''))
        rr = int(i[0])
        print("%d년도 사망건수 %d"%(rr,dd))
print(type(bb))
print(type(cc))
print(type(dd))
f.close()

f = open('drunk.csv',encoding = 'cp949')
data1 = csv.reader(f)

tt = 0

for m in data1 :
    if m[0] == '대구광역시'  and r == '2017':
        tt = int(m[8].replace(',',''))
        rr = int(r)
        print("%d년도 음주운전건수 %d"%(rr,tt))
    elif m[0] == '대구광역시'  and r == '2018':
        tt = int(m[11].replace(',',''))
        rr = int(r)
        print("%d년도 음주운전건수 %d"%(rr,tt))
    elif m[0] == '대구광역시'  and r == '2019':
        tt = int(m[14].replace(',',''))
        rr = int(r)
        print("%d년도 음주운전건수 %d"%(rr,tt))



f.close()









#for i in date :
  #  if t == i[4] and '사고건수' in i[1]:
 #       dd = i[4]
#        print(dd)
# Out:
# 2017~2019: 2017
# 12,870
# 136
# 18,336
# 동구 사고건수 : 1,575
# 동구 사망건수 : 19
# 동구 부장자수 : 2,281
# 중구 사고건수 : 994
# 중구 사망건수 : 6
# 중구 부장자수 : 1,421
# 서구 사고건수 : 1,294
# 서구 사망건수 : 15
# 서구 부장자수 : 1,853
# 남구 사고건수 : 813
# 남구 사망건수 : 9
# 남구 부장자수 : 1,171
# 수성구 사고건수 : 2,012
# 수성구 사망건수 : 20
# 수성구 부장자수 : 2,894
# 달성 사고건수 : 855
# 달성 사망건수 : 26
# 달성 부상자수 : 1,174
# 경북 사고 건수 :  2189
# 경북 사망 건수 :  22
# 경북 부상 자수 :  3035
# 달서구 사고 건수 :  3138
# 달서구 사망 건수 :  3138
# 달서구 사망 건수 :  3138
